# %% [markdown]
# # Установка требуемых пакетов

# %%
#!g1.1
# %pip install torch
# %pip install pytorch-lightning==0.9.0
# %pip install transformers
# %pip install tokenizers==0.10.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: pytorch-lightning==0.9.0 in /home/jupyter/.local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (2.5.1)
# Requirement already satisfied: tokenizers==0.10.2 in /home/jupyter/.local/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (5.3.1)
# Requirement already satisfied: packaging in /kernel/lib/python3.7/site-packages (from pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (20.9)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (0.18.2)
# Requirement already satisfied: tensorboard==2.2.0 in /home/jupyter/.local/lib/python3.7/site-packages (from pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (4.50.0)
# Requirement already satisfied: numpy>=1.16.4 in /kernel/lib/python3.7/site-packages (from pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.19.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/jupyter/.local/lib/python3.7/site-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /kernel/lib/python3.7/site-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (3.3.4)
# Requirement already satisfied: six>=1.10.0 in /home/jupyter/.local/lib/python3.7/site-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/jupyter/.local/lib/python3.7/site-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.33.1)
# Requirement already satisfied: setuptools>=41.0.0 in /kernel/lib/python3.7/site-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (51.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/jupyter/.local/lib/python3.7/site-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.34.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (3.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jupyter/.local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: importlib-metadata in /kernel/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (4.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyter/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /kernel/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /kernel/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /kernel/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jupyter/.local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->-r requirements.txt (line 3)) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->-r requirements.txt (line 3)) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r requirements.txt (line 3)) (2021.7.6)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from transformers->-r requirements.txt (line 3)) (1.12.31)
# Collecting transformers
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 2.5 MB/s
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions in /home/jupyter/.local/lib/python3.7/site-packages (from huggingface-hub==0.0.12->transformers->-r requirements.txt (line 3)) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /kernel/lib/python3.7/site-packages (from packaging->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /kernel/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard==2.2.0->pytorch-lightning==0.9.0->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r requirements.txt (line 3)) (7.1.2)
# Installing collected packages: huggingface-hub, transformers
#   WARNING: The script huggingface-cli is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed huggingface-hub-0.0.12 transformers-4.9.2
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
#!g1.1
import pytorch_lightning as pl
import torch
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks.model_checkpoint import ModelCheckpoint
from tokenizers import BertWordPieceTokenizer
from torch import Tensor
from torch.nn.modules import CrossEntropyLoss, BCEWithLogitsLoss
from torch.utils.data import DataLoader
from transformers import AdamW
from torch.optim import SGD
from typing import Dict
import os
import tqdm
from tqdm import tqdm

# %%
#!g1.1
from datasets.mrc_ner_dataset import MRCNERDataset
from datasets.truncate_dataset import TruncateDataset
from datasets.mrc_ner_dataset import collate_to_max_length
from metrics.query_span_f1 import QuerySpanF1
from models.bert_query_ner import BertQueryNER
from models.query_ner_config import BertQueryNerConfig
from loss import *
from utils.get_parser import get_parser
from utils.random_seed import set_random_seed

# %%
#!g1.1
set_random_seed(0) # Для повторения исследований

# %% [markdown]
# # Задание параметров обучения и модели

# %%
#!g1.1
# Все параметры трейнера задаются в этой ячейке

trainer_args = {
    "default_root_dir" : "logs" , # Куда сохранять модели, логи и т.д.
    "max_epochs" : 16 , # Число эпох для обучения
    "resume_from_checkpoint" : None , # Воспроизвести обучение с чекпойнта
    "val_check_interval" : 0.5 , # Как часто валидировать модель
    "gpus" : 1 # , # число используемых видеокарт
    # Добавьте любые нужные аргументы для конфигурации модели. Их можно найти на 
    # https://pytorch-lightning.readthedocs.io/en/latest/common/trainer.html#trainer-flags
}

# %%
#!g1.1
# Часто изменяемые параметры (не меняющие саму модель) - в этой
CKPT_PATH = "saved_logs/model_10_08-20_47.ckpt" # Путь к чекпойнту, если используется
BERT_PATH = "for_mrc/rubert" # Путь к модели берта
DATA_PATH = "jsons" # Датасет

# %%
#!g1.1
model_args = {
    "data_dir" : DATA_PATH ,
    "bert_config_dir" : BERT_PATH ,
    "pretrained_checkpoint" : CKPT_PATH ,
    "max_length" : 128 , 
    "batch_size" : 32 , 
    "lr" : 2e-5 , 
    "workers" : 8 , 
    "weight_decay" : 0.01 , 
    "warmup_steps" : 0 , 
    "adam_epsilon" : 1e-8 , # Epsilon для алгоритма ADAMW
    "mrc_dropout" : 0.1 , # Dropout вероятность в модели MRC
    "weight_start" : 1.0 , # Коэффициент для стартовых позиций меток (альфа)
    "weight_end" : 1.0 , # Коэффициент для конечных позиций меток (бета)
    "weight_span" : 1.0 , # Коэффициент для спанов меток (гамма)
    "loss_type" : "bce" , 
    "optimizer" : "adamw" ,
    "dice_smooth" : 1e-8 ,
    "final_div_factor" : 1e4 ,
    "span_loss_candidates" : "all" , 
    "accumulate_grad_batches" : 1
}

# %%
#!g1.1
bert_args = {
    "bert_dropout" : 0.1 # Dropout самого берта
}

# %% [markdown]
# # Загрузка модели и данных

# %%
#!g1.1
from models.bert_labeling import BertLabeling

# %%
#!g1.1
# Проверка данных на корректность

dataset_path = os.path.join(DATA_PATH, f"train.json")
vocab_path = os.path.join(BERT_PATH, "vocab.txt") # важно знать, по какому словарю токенизировать
dataset = MRCNERDataset(dataset_path=dataset_path, 
                        tokenizer=BertWordPieceTokenizer(vocab_path, lowercase = False),
                        max_length=128,
                        pad_to_maxlen=False,
                        tag = None # для тестирования по конкретным классам сущностей
                        )

dataloader = DataLoader(
    dataset=dataset,
    batch_size=32,
    num_workers=8,
    shuffle=True,
    collate_fn=collate_to_max_length
)

for batch_idx in tqdm(dataloader):
    pass # Позволяет найти все опечатки, исправить их (ибо вызывается ошибка некорректной токенизации в противном случае)
    # В данный момент все такие опечатки обнуляются

print("All correct!")
# Out:
# 100%|██████████| 8968/8968 [00:55<00:00, 162.69it/s]
# All correct!

# %%
#!g1.1
torch.cuda.empty_cache()

# %%
#!g1.1
model = BertLabeling(model_args, bert_args, trainer_args) # Инициализиуем модель на их основе

# Если грузим из чекпойнта
if model_args["pretrained_checkpoint"]:
    model.load_state_dict(torch.load(model_args["pretrained_checkpoint"], 
                                     map_location=torch.device('cpu'))["state_dict"])
# Out:
# Some weights of BertQueryNER were not initialized from the model checkpoint at for_mrc/rubert and are newly initialized: ['span_embedding.classifier2.bias', 'end_outputs.bias', 'start_outputs.weight', 'start_outputs.bias', 'end_outputs.weight', 'span_embedding.classifier2.weight', 'span_embedding.classifier1.weight', 'span_embedding.classifier1.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-81be17ed723f> in <module>
#       4 if model_args["pretrained_checkpoint"]:
#       5     model.load_state_dict(torch.load(model_args["pretrained_checkpoint"],
# ----> 6                                      map_location=torch.device('cpu'))["state_dict"])
#       7 #
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1043         if len(error_msgs) > 0:
#    1044             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1045                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1046         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1047
#
# RuntimeError: Error(s) in loading state_dict for BertLabeling:
# 	Missing key(s) in state_dict: "model.bert.embeddings.position_ids".
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py:828: UserWarning: The following variables cannot be serialized: model
#   warnings.warn(message)

# %% [markdown]
# # Обучение

# %%
#!g1.1
checkpoint_callback = ModelCheckpoint(
    # Директория, куда будут сохраняться чекпойнты и логи (по умолчанию корневая папка проекта)
    filepath=trainer_args["default_root_dir"], 
    save_top_k=5, # Сохранять топ 5 моделей по метрике monitor
    verbose=True, # Уведомлять о результатах валидации
    monitor="span_f1", # Метрика для подсчета качества модели, см. span_f1
    period=-1, # Сохранять чекпойнты каждую эпоху
    mode="max", # Сохраняем самые максимальные по метрике модели
)

# Инициализация Trainer на основе аргументов командной строки 
# Настройка сохранения моделей через callbacks
trainer = Trainer(**trainer_args, checkpoint_callback = checkpoint_callback)
# Out:
# /home/jupyter/.local/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Checkpoint directory logs exists and is not empty with save_top_k != 0.All files in this directory will be deleted when a checkpoint is saved!
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]

# %%
#!g1.1
trainer.fit(model) # Запуск процесса обучения и валидации, с мониторингом
# Out:
# HBox(children=(HTML(value='Validation sanity check'), FloatProgress(value=1.0, bar_style='info', layout=Layout…
# HBox(children=(HTML(value='Training'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), max…
# 1
# HBox(children=(HTML(value='Validation sanity check'), FloatProgress(value=1.0, bar_style='info', layout=Layout…
# HBox(children=(HTML(value='Training'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), max…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# {'id': '7395.22', 'context': 'Неизвестный поклонник Эдгара ПоПерезахоронение Эдгара По.', 'tag': 'PERSON', 'query': 'Человек - мужчина, женщина или ребенок.', 'filename': '3948_text', 'exists': True, 'start_positions': [22, 47], 'end_positions': [31, 56], 'span_positions': ['22;31', '47;56'], 'spans': ['Эдгара По', 'Эдгара По']}
# {'id': '8997.6', 'context': 'Кроме того, сообщалось, что 69-летний Т.Чхеидзе, который руководил БДТ с 2007г., уже выставил на продажу свою петербургскую квартиру и собирается вернуться в Тбилиси, где живет его семья.', 'tag': 'DATE', 'query': 'Дата - это номер дня в месяце, часто указываемый в сочетании с названием дня, месяца и года.', 'filename': '633', 'exists': True, 'start_positions': [71], 'end_positions': [77], 'span_positions': ['71;77'], 'spans': ['с 2007']}
# {'id': '5013.18', 'context': 'Самолёт «Як-18Т»\nСообщение об этой авиационной катастрофе поступило в ЦУКС МЧС России по Архангельской области в 16 часов 25 минут.', 'tag': 'NUMBER', 'query': 'Число - это знак или символ, представляющий единицу, которая является частью системы подсчета и расчета.', 'filename': '19528_text', 'exists': True, 'start_positions': [12], 'end_positions': [14], 'span_positions': ['12;14'], 'spans': ['18']}
# {'id': '1752.22', 'context': "Ли Джэён\nЮжнокорейский суд центрального округа Сеула выдал ордер на арест фактического главы ''Samsung'' Ли ДжэёнТакже Ли Чже Ен, Ли Чже Ён ().", 'tag': 'PERSON', 'query': 'Человек - мужчина, женщина или ребенок.', 'filename': '112444_text', 'exists': True, 'start_positions': [0, 105, 119, 130], 'end_positions': [8, 113, 128, 139], 'span_positions': ['0;8', '105;113', '119;128', '130;139'], 'spans': ['Ли Джэён', 'Ли Джэён', 'Ли Чже Ен', 'Ли Чже Ён']}
# {'id': '8605.20', 'context': 'Cамым честным вариантом станет проведение досрочных выборов в Государственное собраниеЦитата скомпилирована по разным источникам..\n\nРанее в отставку подал министра финансов Андрей Бертончель.', 'tag': 'ORGANIZATION', 'query': 'Организация - это компания или другая группа людей, которые работают вместе для определенной цели.', 'filename': '535058_text', 'exists': True, 'start_positions': [62], 'end_positions': [86], 'span_positions': ['62;86'], 'spans': ['Государственное собрание']}
# {'id': '1763.22', 'context': "Ли Джэён фактически является главой ''Samsung Group'' после того, как в 2014 году тяжело заболел его отец Ли ГонхиТакже Ли Кун Хи ().", 'tag': 'PERSON', 'query': 'Человек - мужчина, женщина или ребенок.', 'filename': '112444_text', 'exists': True, 'start_positions': [0, 106, 120], 'end_positions': [8, 114, 129], 'span_positions': ['0;8', '106;114', '120;129'], 'spans': ['Ли Джэён', 'Ли Гонхи', 'Ли Кун Хи']}
# {'id': '5020.18', 'context': 'По предварительным данным эта страшная трагедия произошла из-за того, что пилот самолёта «Як-18Т» пытался лететь на малой высоте над деревьями и случайно зацепил их.', 'tag': 'NUMBER', 'query': 'Число - это знак или символ, представляющий единицу, которая является частью системы подсчета и расчета.', 'filename': '19528_text', 'exists': True, 'start_positions': [93], 'end_positions': [95], 'span_positions': ['93;95'], 'spans': ['18']}
# {'id': '5014.18', 'context': 'Одномоторный самолёт «Як-18Т» выполнял полёты по заявке с 11:00 до 17:00 МСК в районе аэродрома «Лахта» близ Катунино.', 'tag': 'NUMBER', 'query': 'Число - это знак или символ, представляющий единицу, которая является частью системы подсчета и расчета.', 'filename': '19528_text', 'exists': True, 'start_positions': [25], 'end_positions': [27], 'span_positions': ['25;27'], 'spans': ['18']}
# {'id': '4833.15', 'context': 'Согласно оглашенному в понедельник решению Страсбургского суда, массовый расстрел польских военнослужащих и чиновников под Катынью являлся военным преступлением.', 'tag': 'LOCATION', 'query': 'Местоположение - это место или позиция.', 'filename': '18805_text', 'exists': True, 'start_positions': [119], 'end_positions': [129], 'span_positions': ['119;129'], 'spans': ['под Катынь']}
# 1
# /home/jupyter/.local/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Could not log computational graph since the `model.example_input_array` attribute is not set or `input_array` was not given
#   warnings.warn(*args, **kwargs)
#
#   | Name     | Type              | Params
# -----------------------------------------------
# 0 | model    | BertQueryNER      | 180 M
# 1 | bce_loss | BCEWithLogitsLoss | 0
# 2 | span_f1  | QuerySpanF1       | 0
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
# /home/jupyter/.local/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)
# Saving latest checkpoint..
# /home/jupyter/.local/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Could not log computational graph since the `model.example_input_array` attribute is not set or `input_array` was not given
#   warnings.warn(*args, **kwargs)
#
#   | Name     | Type              | Params
# -----------------------------------------------
# 0 | model    | BertQueryNER      | 180 M
# 1 | bce_loss | BCEWithLogitsLoss | 0
# 2 | span_f1  | QuerySpanF1       | 0
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
#
# Epoch 00000: span_f1 reached 0.74263 (best 0.74263), saving model to logs/epoch=0.ckpt as top 5
#
# Epoch 00000: span_f1 reached 0.78588 (best 0.78588), saving model to logs/epoch=0_v0.ckpt as top 5
#
# Epoch 00001: span_f1 reached 0.80479 (best 0.80479), saving model to logs/epoch=1.ckpt as top 5
#
# Epoch 00001: span_f1 reached 0.82020 (best 0.82020), saving model to logs/epoch=1_v0.ckpt as top 5
#
# Epoch 00002: span_f1 reached 0.81910 (best 0.82020), saving model to logs/epoch=2.ckpt as top 5
#
# Epoch 00002: span_f1 reached 0.83123 (best 0.83123), saving model to logs/epoch=2_v0.ckpt as top 5
#
# Epoch 00003: span_f1 reached 0.83366 (best 0.83366), saving model to logs/epoch=3.ckpt as top 5
#
# Epoch 00003: span_f1 reached 0.83773 (best 0.83773), saving model to logs/epoch=3_v0.ckpt as top 5
#
# Epoch 00004: span_f1 reached 0.83044 (best 0.83773), saving model to logs/epoch=4.ckpt as top 5
#
# Epoch 00004: span_f1 reached 0.82705 (best 0.83773), saving model to logs/epoch=4_v0.ckpt as top 5
#
# Epoch 00005: span_f1 reached 0.82900 (best 0.83773), saving model to logs/epoch=5.ckpt as top 5
#
# Epoch 00005: span_f1  was not in top 5
#
# Epoch 00006: span_f1  was not in top 5
#
# Epoch 00006: span_f1 reached 0.83219 (best 0.83773), saving model to logs/epoch=6.ckpt as top 5
#
# Epoch 00007: span_f1  was not in top 5
#
# Epoch 00007: span_f1 reached 0.83159 (best 0.83773), saving model to logs/epoch=7.ckpt as top 5
#
# Epoch 00008: span_f1 reached 0.83345 (best 0.83773), saving model to logs/epoch=8.ckpt as top 5
#
# Epoch 00008: span_f1 reached 0.83230 (best 0.83773), saving model to logs/epoch=8_v0.ckpt as top 5
#
# Epoch 00009: span_f1 reached 0.83573 (best 0.83773), saving model to logs/epoch=9.ckpt as top 5
#
# Epoch 00009: span_f1 reached 0.83340 (best 0.83773), saving model to logs/epoch=9_v0.ckpt as top 5
#
# Epoch 00010: span_f1  was not in top 5
#
# Epoch 00010: span_f1 reached 0.83757 (best 0.83773), saving model to logs/epoch=10.ckpt as top 5
#
# Epoch 00011: span_f1 reached 0.83597 (best 0.83773), saving model to logs/epoch=11.ckpt as top 5
#
# Epoch 00011: span_f1 reached 0.83616 (best 0.83773), saving model to logs/epoch=11_v0.ckpt as top 5
#
# Epoch 00012: span_f1  was not in top 5
#
# Epoch 00012: span_f1 reached 0.83668 (best 0.83773), saving model to logs/epoch=12.ckpt as top 5
#
# Epoch 00013: span_f1 reached 0.83841 (best 0.83841), saving model to logs/epoch=13.ckpt as top 5
#
# Epoch 00013: span_f1 reached 0.83861 (best 0.83861), saving model to logs/epoch=13_v0.ckpt as top 5
#
# Epoch 00014: span_f1 reached 0.84160 (best 0.84160), saving model to logs/epoch=14.ckpt as top 5
#
# Epoch 00014: span_f1 reached 0.84038 (best 0.84160), saving model to logs/epoch=14_v0.ckpt as top 5
#
# Epoch 00015: span_f1 reached 0.83974 (best 0.84160), saving model to logs/epoch=15.ckpt as top 5
#
# Epoch 00015: span_f1 reached 0.84031 (best 0.84160), saving model to logs/epoch=15_v0.ckpt as top 5
# Saving latest checkpoint..
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py:828: UserWarning: The following variables cannot be serialized: checkpoint_callback, model, trainer
#   warnings.warn(message)

# %% [markdown]
# # Тестирование

# %%
#!g1.1
# Задать пути к модели, данным и словарю
CHECKPOINTS = "saved_logs/model_10_08-20_47.ckpt"
DATASET_PATH = "jsons/test.json"
VOCAB_PATH = "for_mrc/rubert/vocab.txt"

# %%
#!g1.1
checkpoint_callback = ModelCheckpoint(
    filepath=CHECKPOINTS, 
    save_top_k=-1, # не сохранять
    verbose=False, # не уведомлять
    monitor="span_f1", 
    period=1,
    mode="max",
)

trainer = Trainer(**trainer_args, checkpoint_callback = checkpoint_callback)

# %%
#!g1.1
model.output_test_file = open("test_dataset.out", "w", encoding = "utf-8")
trainer.test(model, model.get_dataloader("test", tag = None)) # Тестирование по всем классам

# %%
#!g1.1
model.output_test_file = open("test_dataset.out", "w", encoding = "utf-8")
trainer.test(model, model.get_dataloader("test", tag = "PERSON")) # Тестирование по отдельным классам
# Out:
# /home/jupyter/.local/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Could not log computational graph since the `model.example_input_array` attribute is not set or `input_array` was not given
#   warnings.warn(*args, **kwargs)
# HBox(children=(HTML(value='Testing'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'span_f1': tensor(0.9674, device='cuda:0'),
#  'span_fn': tensor(27, device='cuda:0'),
#  'span_fp': tensor(36, device='cuda:0'),
#  'span_precision': tensor(0.9629, device='cuda:0'),
#  'span_recall': tensor(0.9719, device='cuda:0'),
#  'span_tp': tensor(935, device='cuda:0'),
#  'val_loss': tensor(0.0106, device='cuda:0')}
# --------------------------------------------------------------------------------
# [{'val_loss': 0.010555455461144447,
#   'span_precision': 0.9629248380661011,
#   'span_recall': 0.9719334840774536,
#   'span_f1': 0.9674081802368164,
#   'span_tp': 935,
#   'span_fp': 36,
#   'span_fn': 27}]
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py:828: UserWarning: The following variables cannot be serialized: checkpoint_callback, model, trainer
#   warnings.warn(message)

# %%
#!g1.1
